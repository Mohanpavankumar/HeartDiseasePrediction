# %% [markdown]
# # Heart Disease Prediction using Machine Learning Algorithms

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.cm import rainbow
# %matplotlib inline

import os
print(os.listdir())

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn import *

from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
# Out:
# ['.ipynb_checkpoints', 'app.py', 'dnn_model.pkl', 'dt_model.pkl', 'fnn_model.pkl', 'heart.csv', 'Heart_Disease_Prediction.ipynb', 'knn_classifier.pkl', 'lr_model.pkl', 'mlp_model.pkl', 'rf_model.pkl', 'svm_model.pkl', 'templates']

# %%
heartData = pd.read_csv("C:/Users/mohan/Documents/Projects/HeartDiseasePrediction/heart.csv")
heartData.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heartData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
heartData.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
info = ["age","1: male, 0: female","chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic","resting blood pressure"," serum cholestoral in mg/dl","fasting blood sugar > 120 mg/dl","resting electrocardiographic results (values 0,1,2)"," maximum heart rate achieved","exercise induced angina","oldpeak = ST depression induced by exercise relative to rest","the slope of the peak exercise ST segment","number of major vessels (0-3) colored by flourosopy","thal: 3 = normal; 6 = fixed defect; 7 = reversable defect"]



for i in range(len(info)):
    print(heartData.columns[i]+":\t\t\t"+info[i])
# Out:
# age:			age
# sex:			1: male, 0: female
# cp:			chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic
# trestbps:			resting blood pressure
# chol:			 serum cholestoral in mg/dl
# fbs:			fasting blood sugar > 120 mg/dl
# restecg:			resting electrocardiographic results (values 0,1,2)
# thalach:			 maximum heart rate achieved
# exang:			exercise induced angina
# oldpeak:			oldpeak = ST depression induced by exercise relative to rest
# slope:			the slope of the peak exercise ST segment
# ca:			number of major vessels (0-3) colored by flourosopy
# thal:			thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %% [markdown]
# # Missing Percentage

# %%
missing_percentage = (heartData.isnull().sum() / len(heartData)) * 100
print(missing_percentage)
# Out:
# age         0.0
# sex         0.0
# cp          0.0
# trestbps    0.0
# chol        0.0
# fbs         0.0
# restecg     0.0
# thalach     0.0
# exang       0.0
# oldpeak     0.0
# slope       0.0
# ca          0.0
# thal        0.0
# target      0.0
# dtype: float64

# %%
corr = heartData.corr()
corr.style.background_gradient(cmap='Spectral')
# Out:
# <style  type="text/css" >
# #T_3ebb642f_a209_11ef_a23b_841b77ad899frow0_col0,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow1_col1,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow2_col2,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow3_col3,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow4_col4,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow5_col5,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow6_col6,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow7_col7,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow8_col8,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow9_col9,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow10_col10,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow11_col11,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow12_col12,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow13_col13{
#             background-color:  #5e4fa2;
#             color:  #f1f1f1;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow0_col1,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow8_col5{
#             background-color:  #e1504b;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow0_col2,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow4_col13,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow6_col12{
#             background-color:  #f7844e;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow0_col3{
#             background-color:  #fecc7b;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow0_col4,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow1_col10,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow4_col8{
#             background-color:  #fdc776;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow0_col5,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow1_col0,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow10_col6{
#             background-color:  #f47044;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow0_col6,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow6_col3{
#             background-color:  #a40844;
#             color:  #f1f1f1;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow0_col7,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow1_col4,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow4_col6,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow6_col5,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow7_col0,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow8_col2,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow8_col13,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow9_col10,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow9_col13,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow10_col9,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow13_col1,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow13_col3,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow13_col8,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow13_col11,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow13_col12{
#             background-color:  #9e0142;
#             color:  #f1f1f1;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow0_col8,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow11_col12{
#             background-color:  #fece7c;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow0_col9{
#             background-color:  #fffebe;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow0_col10,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow1_col2,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow2_col9{
#             background-color:  #f99153;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow0_col11,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow3_col0,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow11_col0{
#             background-color:  #fff7b2;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow0_col12,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow11_col1,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow12_col10{
#             background-color:  #fdb163;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow0_col13,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow7_col4{
#             background-color:  #e3534a;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow1_col3{
#             background-color:  #ba2049;
#             color:  #f1f1f1;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow1_col5,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow4_col5,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow10_col8{
#             background-color:  #da464d;
#             color:  #f1f1f1;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow1_col6,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow13_col4{
#             background-color:  #c9314c;
#             color:  #f1f1f1;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow1_col7,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow13_col6{
#             background-color:  #f88950;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow1_col8,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow1_col12,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow8_col12{
#             background-color:  #fee08b;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow1_col9,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow6_col10{
#             background-color:  #fee695;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow1_col11,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow4_col10{
#             background-color:  #feca79;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow1_col13,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow12_col6{
#             background-color:  #d8434e;
#             color:  #f1f1f1;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow2_col0,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow4_col2,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow11_col4{
#             background-color:  #f67f4b;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow2_col1,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow6_col0{
#             background-color:  #ef6645;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow2_col3,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow10_col4{
#             background-color:  #e55749;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow2_col4{
#             background-color:  #d23a4e;
#             color:  #f1f1f1;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow2_col5,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow2_col6{
#             background-color:  #e95c47;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow2_col7{
#             background-color:  #ffffbe;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow2_col8{
#             background-color:  #ab0f45;
#             color:  #f1f1f1;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow2_col10{
#             background-color:  #feefa3;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow2_col11{
#             background-color:  #e45549;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow2_col12,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow11_col7{
#             background-color:  #de4c4b;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow2_col13{
#             background-color:  #e1f399;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow3_col1,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow10_col0{
#             background-color:  #e75948;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow3_col2,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow6_col7{
#             background-color:  #fdb567;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow3_col4{
#             background-color:  #fa9b58;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow3_col5,#T_3ebb642f_a209_11ef_a23b_841b77ad899frow6_col8{
#             background-color:  #f99355;
#             color:  #000000;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow3_col6{
#             background-color:  #a90d45;
#             color:  #f1f1f1;
#         }#T_3ebb642f_a209_11ef_a23b_841b77ad899frow3_col7{
#             backgrou

# %%
X = heartData.drop(['target'], axis = 1)
y = heartData['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
print("X_train ->",X_train.shape[0], "X_Test ->",X_test.shape[0], "Y_Train ->", y_train.shape[0], "Y_Test ->", y_test.shape[0])

# standardise the dataset
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# X_train -> 717 X_Test -> 308 Y_Train -> 717 Y_Test -> 308

# %%
# Reduce Dimensionality for Plotting (Using PCA)
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC
# Define the kernels to test
kernels = ['linear', 'poly', 'rbf', 'sigmoid']
accuracies = []

# Train SVM with each kernel and store the accuracy
for kernel in kernels:
    svc = SVC(kernel=kernel, random_state=0)
    svc.fit(X_train, y_train)
    y_pred = svc.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)

# Plotting the accuracies as a bar graph
plt.figure(figsize=(10, 6))
bars = plt.bar(kernels, accuracies, color=['skyblue', 'salmon', 'lightgreen', 'violet'])
plt.xlabel('Kernel Type')
plt.ylabel('Accuracy')
plt.title('SVM Accuracy with Different Kernels')
plt.ylim(0, 1)  # Setting y-axis limit for easier comparison

# Display decimal values on top of each bar
for bar in bars:
    yval = bar.get_height()  # Get the height (accuracy) of the bar
    plt.text(bar.get_x() + bar.get_width() / 2, yval,  # Place text slightly above each bar
             f'{yval:.2f}', ha='center', va='bottom', fontsize=12)  # Format as decimal with 2 places
    
plt.show()

clf = SVC(random_state=0)
clf.fit(X_train, y_train)

y_pred_all = clf.predict(X_test)
overall_accuracy = accuracy_score(y_test, y_pred_all)

# Print overall accuracy
print(f"Overall accuracy using all features: {overall_accuracy:.2f}")
# Out:
# Overall accuracy using all features: 0.68

# %% [markdown]
# # K Nearest Neighbors

# %%
knn_scores = []
for k in range(2,21) :
    knn_classifier = KNeighborsClassifier(n_neighbors = k)
    knn_classifier.fit(X_train, y_train)
    knn_score=round(knn_classifier.score(X_test, y_test),2)
    knn_scores.append(knn_score)
knn_classifier = KNeighborsClassifier(n_neighbors= 5)
knn_classifier.fit(X_train, y_train)
knn_score=knn_classifier.predict(X_test)
print (classification_report(y_test,knn_score))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       145
#            1       0.88      0.88      0.88       163
#
#     accuracy                           0.88       308
#    macro avg       0.88      0.88      0.88       308
# weighted avg       0.88      0.88      0.88       308

# %%
plt.figure(figsize=(10, 6))
plt.plot([k for k in range(2, 21)], knn_scores, color = 'red')
for i in range (2,21):
    plt. text(i, knn_scores[i-2], (i, knn_scores[i-2]))
plt.xticks([i for i in range(2, 21)])
plt.xlabel( 'Number of Neighbors (K)')
plt. ylabel('Scores')
plt.title('KNN Scores for different K neighbouras')
# Out:
# Text(0.5, 1.0, 'KNN Scores for different K neighbouras')

# %% [markdown]
# # Decision Tree

# %%
dt_scores = []
for i in range(1, len(X.columns) + 1):
    dt_classifier = DecisionTreeClassifier(max_features = i, random_state = 0)
    dt_classifier.fit(X_train, y_train)
    dt_scores.append(round(dt_classifier.score(X_test, y_test),2))
print ("Done")
# Out:
# Done

# %%
print(dt_scores)
# Out:
# [0.96, 0.96, 0.99, 0.99, 1.0, 0.98, 0.98, 0.98, 0.98, 0.97, 0.98, 0.96, 0.97]

# %%
dt_classifier = DecisionTreeClassifier(max_features = 13, random_state = 0)
dt_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_features=13, random_state=0)

# %%
plt.figure(figsize=(10, 6))
plt.plot([i for i in range(1, len(X.columns) + 1)], dt_scores, color = 'green')
for i in range(1, len(X.columns) + 1):
    plt.text(i, dt_scores[i-1], (i,dt_scores[i-1]))
plt.xticks([i for i in  range(1, len(X.columns) +1)])
plt.xlabel( 'Max features')
plt. ylabel('Scores')
plt.title("Decision Tree Classifier  scores for different number of maximum features")
# Out:
# Text(0.5, 1.0, 'Decision Tree Classifier  scores for different number of maximum features')

# %% [markdown]
# # Logistic Regression

# %%
logistic_model = LogisticRegression()

logistic_model.fit(X_train,y_train)

y_pred_lr = logistic_model.predict(X_test)

# %%
score_lr = round(accuracy_score(y_pred_lr,y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
print(classification_report(y_test, y_pred_lr))
# Out:
# The accuracy score achieved using Logistic Regression is: 81.17 %
#               precision    recall  f1-score   support
#
#            0       0.86      0.76      0.81       159
#            1       0.77      0.87      0.82       149
#
#     accuracy                           0.81       308
#    macro avg       0.82      0.81      0.81       308
# weighted avg       0.82      0.81      0.81       308

# %% [markdown]
# # Random Forest

# %% [markdown]
# ### I have taken estimatore as 100

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=0)

# Train the model using the training set
rf_model.fit(X_train, y_train)

# Step 4: Make predictions
y_pred = rf_model.predict(X_test)

# Step 5: Evaluate the model
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Calculate accuracy, confusion matrix, and classification report
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print(f"Accuracy: {accuracy}")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)
# Out:
# Accuracy: 0.9805194805194806
# Confusion Matrix:
# [[159   0]
#  [  6 143]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       159
#            1       1.00      0.96      0.98       149
#
#     accuracy                           0.98       308
#    macro avg       0.98      0.98      0.98       308
# weighted avg       0.98      0.98      0.98       308

# %% [markdown]
# # Bar Graph based on all accuracies obtained by different algoritms

# %%
import matplotlib.pyplot as plt

algorithms = ['SVM', 'KNN', 'Decision Tree','Logistic Regression', 'Random Forest']
accuracies = [0.81, 0.71, 0.97, 0.81, 0.98]  

# Create the bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(algorithms, accuracies, color='lightgreen')

# Add accuracy scores on top of each bar
for bar in bars:
    height = bar.get_height()  # Get the height of the bar (accuracy score)
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}', 
             ha='center', va='bottom', fontsize=12)

# Add labels and title
plt.xlabel('Algorithms', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.title('Comparison of Heart Disease Prediction Algorithms', fontsize=14)

# Display the plot
plt.ylim(0, 1)  # To ensure the accuracy values are within the 0-1 range
plt.show()

# %% [markdown]
# # Save Models in file

# %%
'''import pickle

all_models=[rf_model, logistic_model,dt_classifier,svc, knn_classifier]
with open ("models.pkl",'wb') as files:
    pickle.dump (all_models, files)
print ("Models saved successfully.")'''

import joblib

# Assuming you have your trained models in variables: svm_model, dt_model, lr_model, rf_model

# Save models to files
joblib.dump(svc, 'svm_model.pkl')
joblib.dump(dt_classifier, 'dt_model.pkl')
joblib.dump(logistic_model, 'lr_model.pkl')
joblib.dump(rf_model, 'rf_model.pkl')
joblib.dump(knn_classifier, 'knn_classifier.pkl')
# Out:
# ['knn_classifier.pkl']

# %% [markdown]
# # Heart Disease Prediction using Deep Learning Algorithms

# %% [markdown]
# # Feedforward Neural Networks(FNN)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dropout

# Build FNN model
fnn_model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')  # For binary classification
])

# Compile the model
fnn_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = fnn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Evaluate the model
y_pred = (fnn_model.predict(X_test) > 0.5).astype("int32")
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(classification_report(y_test, y_pred))
# Out:
# Epoch 1/50
# 18/18 [==============================] - 3s 39ms/step - loss: 3.0260 - accuracy: 0.5271 - val_loss: 1.3837 - val_accuracy: 0.5556
# Epoch 2/50
# 18/18 [==============================] - 0s 10ms/step - loss: 1.4978 - accuracy: 0.5585 - val_loss: 1.8119 - val_accuracy: 0.5556
# Epoch 3/50
# 18/18 [==============================] - 0s 10ms/step - loss: 1.1561 - accuracy: 0.5864 - val_loss: 0.9945 - val_accuracy: 0.5903
# Epoch 4/50
# 18/18 [==============================] - 0s 10ms/step - loss: 0.9020 - accuracy: 0.5916 - val_loss: 1.0893 - val_accuracy: 0.5694
# Epoch 5/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0
50
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3438 - accuracy: 0.8569 - val_loss: 0.5512 - val_accuracy: 0.7708
# Epoch 38/50
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3682 - accuracy: 0.8482 - val_loss: 0.5612 - val_accuracy: 0.7431
# Epoch 39/50
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3466 - accuracy: 0.8586 - val_loss: 0.5710 - val_accuracy: 0.7431
# Epoch 40/50
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3218 - accuracy: 0.8604 - val_loss: 0.5154 - val_accuracy: 0.7778
# Epoch 41/50
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3636 - accuracy: 0.8412 - val_loss: 0.5523 - val_accuracy: 0.7500
# Epoch 42/50
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3190 - accuracy: 0.8604 - val_loss: 0.6486 - val_accuracy: 0.7222
# Epoch 43/50
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4130 - accuracy: 0.8098 - val_loss: 0.7779 - val_accuracy: 0.6875
# Epoch 44/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3944 - accuracy: 0.8342 - val_loss: 0.6044 - val_accuracy: 0.7500
# Epoch 45/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3528 - accuracy: 0.8517 - val_loss: 0.5383 - val_accuracy: 0.7778
# Epoch 46/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3088 - accuracy: 0.8778 - val_loss: 0.5658 - val_accuracy: 0.7500
# Epoch 47/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3251 - accuracy: 0.8621 - val_loss: 0.5252 - val_accuracy: 0.7778
# Epoch 48/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3576 - accuracy: 0.8499 - val_loss: 0.7721 - val_accuracy: 0.6875
# Epoch 49/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3570 - accuracy: 0.8482 - val_loss: 0.5416 - val_accuracy: 0.7778
# Epoch 50/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3302 - accuracy: 0.8517 - val_loss: 0.5314 - val_accuracy: 0.7569
# 10/10 [==============================] - 0s 3ms/step
# Accuracy: 0.788961038961039
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       159
#            1       0.77      0.81      0.79       149
#
#     accuracy                           0.79       308
#    macro avg       0.79      0.79      0.79       308
# weighted avg       0.79      0.79      0.79       308

# %% [markdown]
# # Multilayer Perceptrons(MLP)

# %%
# Build the MLP model
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dropout

mlp_model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(16, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])


# Compile the model
mlp_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = mlp_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
y_pred = (mlp_model.predict(X_test) > 0.5).astype("int32")
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(classification_report(y_test, y_pred))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 6s 54ms/step - loss: 0.9107 - accuracy: 0.5288 - val_loss: 5.2651 - val_accuracy: 0.5347
# Epoch 2/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.7640 - accuracy: 0.6038 - val_loss: 2.2824 - val_accuracy: 0.5347
# Epoch 3/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.6976 - accuracy: 0.6422 - val_loss: 1.0573 - val_accuracy: 0.5556
# Epoch 4/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.6661 - accuracy: 0.6353 - val_loss: 0.6775 - val_accuracy: 0.6181
# Epoch 5/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.6778 - accuracy: 0.6614 - val_loss: 0.6394 - val_accuracy: 0.6319
# Epoch 6/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.6713 - accuracy: 0.6667 - val_loss: 0.6406 - val_accuracy: 0.6597
# Epoch 7/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.6608 - accuracy: 0.6736 - val_loss: 0.6399 - val_accuracy: 0.6597
# Epoch 8/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.6658 - accuracy: 0.6824 - val_loss: 0.6465 - val_accuracy: 0.6736
# Epoch 9/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.6442 - accuracy: 0.6876 - val_loss: 0.6705 - val_accuracy: 0.6667
# Epoch 10/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.6191 - accuracy: 0.6806 - val_loss: 0.6861 - val_accuracy: 0.6319
# Epoch 11/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.
100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3857 - accuracy: 0.8447 - val_loss: 1.5180 - val_accuracy: 0.5069
# Epoch 75/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3726 - accuracy: 0.8447 - val_loss: 0.9199 - val_accuracy: 0.5972
# Epoch 76/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3780 - accuracy: 0.8307 - val_loss: 1.1941 - val_accuracy: 0.5347
# Epoch 77/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3875 - accuracy: 0.8307 - val_loss: 1.0854 - val_accuracy: 0.5486
# Epoch 78/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3642 - accuracy: 0.8429 - val_loss: 0.5163 - val_accuracy: 0.7639
# Epoch 79/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3697 - accuracy: 0.8551 - val_loss: 0.5343 - val_accuracy: 0.7361
# Epoch 80/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3726 - accuracy: 0.8412 - val_loss: 0.5855 - val_accuracy: 0.7153
# Epoch 81/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3796 - accuracy: 0.8080 - val_loss: 0.5499 - val_accuracy: 0.7431
# Epoch 82/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.3613 - accuracy: 0.8464 - val_loss: 0.6108 - val_accuracy: 0.6736
# Epoch 83/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3679 - accuracy: 0.8412 - val_loss: 0.5011 - val_accuracy: 0.7708
# Epoch 84/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.3456 - accuracy: 0.8639 - val_loss: 0.5006 - val_accuracy: 0.7639
# Epoch 85/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3247 - accuracy: 0.8674 - val_loss: 0.7711 - val_accuracy: 0.6250
# Epoch 86/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.3595 - accuracy: 0.8586 - val_loss: 0.4961 - val_accuracy: 0.7986
# Epoch 87/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.3798 - accuracy: 0.8272 - val_loss: 0.7648 - val_accuracy: 0.5972
# Epoch 88/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.3852 - accuracy: 0.8290 - val_loss: 0.5540 - val_accuracy: 0.7569
# Epoch 89/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.3567 - accuracy: 0.8639 - val_loss: 0.4928 - val_accuracy: 0.7639
# Epoch 90/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.4080 - accuracy: 0.8150 - val_loss: 0.4902 - val_accuracy: 0.7917
# Epoch 91/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3619 - accuracy: 0.8551 - val_loss: 0.5482 - val_accuracy: 0.7292
# Epoch 92/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3993 - accuracy: 0.8307 - val_loss: 0.4914 - val_accuracy: 0.7847
# Epoch 93/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3470 - accuracy: 0.8482 - val_loss: 0.5219 - val_accuracy: 0.7778
# Epoch 94/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3663 - accuracy: 0.8534 - val_loss: 0.5351 - val_accuracy: 0.7639
# Epoch 95/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3709 - accuracy: 0.8360 - val_loss: 0.5110 - val_accuracy: 0.7708
# Epoch 96/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3795 - accuracy: 0.8499 - val_loss: 0.4920 - val_accuracy: 0.8056
# Epoch 97/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.3458 - accuracy: 0.8551 - val_loss: 0.5096 - val_accuracy: 0.7708
# Epoch 98/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.3767 - accuracy: 0.8412 - val_loss: 0.5229 - val_accuracy: 0.7708
# Epoch 99/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3448 - accuracy: 0.8551 - val_loss: 0.5117 - val_accuracy: 0.7778
# Epoch 100/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.3644 - accuracy: 0.8482 - val_loss: 0.4925 - val_accuracy: 0.7986
# 10/10 [==============================] - 0s 4ms/step
# Accuracy: 0.8311688311688312
#               precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82       159
#            1       0.77      0.93      0.84       149
#
#     accuracy                           0.83       308
#    macro avg       0.84      0.83      0.83       308
# weighted avg       0.85      0.83      0.83       308

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(14, 5))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='best')

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Deep Neural Network

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Build the DNN model
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

# Define early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, 
                    validation_split=0.2, 
                    epochs=50, 
                    batch_size=32, 
                    callbacks=[early_stopping],
                    verbose=1)

# Evaluate the model on the test set
y_pred = (model.predict(X_test) > 0.5).astype("int32")
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy on test data: {accuracy:.2f}')
print(classification_report(y_test, y_pred))

# Plot training and validation loss over epochs
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1/100
# 18/18 [==============================] - 3s 35ms/step - loss: 7.2474 - accuracy: 0.5375 - val_loss: 1.3267 - val_accuracy: 0.4931
# Epoch 2/100
# 18/18 [==============================] - 0s 11ms/step - loss: 4.1349 - accuracy: 0.5044 - val_loss: 1.2726 - val_accuracy: 0.5625
# Epoch 3/100
# 18/18 [==============================] - 0s 11ms/step - loss: 3.0994 - accuracy: 0.5009 - val_loss: 0.7545 - val_accuracy: 0.5972
# Epoch 4/100
# 18/18 [==============================] - 0s 11ms/step - loss: 2.4767 - accuracy: 0.5009 - val_loss: 0.7550 - val_accuracy: 0.5972
# Epoch 5/100
# 18/18 [==============================] - 0s 11ms/step - loss: 2.0136 - accuracy: 0.5393 - val_loss: 0.9964 - val_accuracy: 0.5139
# Epoch 6/100
# 18/18 [==============================] - 0s 11ms/step - loss: 1.6623 - accuracy: 0.5462 - val_loss: 0.9988 - val_accuracy: 0.5139
# Epoch 7/100
# 18/18 [==============================] - 0s 11ms/step - loss: 1.4328 - accuracy: 0.5654 - val_loss: 0.7026 - val_accuracy: 0.5903
# Epoch 8/100
# 18/18 [==============================] - 0s 11ms/step - loss: 1.3725 - accuracy: 0.5410 - val_loss: 0.7325 - val_accuracy: 0.6042
# Epoch 9/100
# 18/18 [==============================] - 0s 11ms/step - loss: 1.4320 - accuracy: 0.5323 - val_loss: 0.7591 - val_accuracy: 0.5625
# Epoch 10/100
# 18/18 [==============================] - 0s 11ms/step - loss: 1.2585 - accuracy: 0.5358 - val_loss: 0.9127 - val_accuracy: 0.5069
# Epoch 11/100
# 18/18 [==============================] - 0s 11ms/step - loss: 1.1278 - accuracy: 0.5742 - val_loss: 0.6644 - val_accuracy: 0.6111
# Epoch 12/100
# 18/18 [==============================] - 0s 10ms/step - loss: 1.1258 - accuracy: 0.5794 - val_loss: 0.6733 - val_accuracy: 0.6042
# Epoch 13/100
# 18/18 [==============================] - 0s 11ms/step - loss: 1.0656 - accuracy: 0.5724 - val_loss: 0.6702 - val_accuracy: 0.6111
# Epoch 14/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.8640 - accuracy: 0.6248 - val_loss: 0.7766 - val_accuracy: 0.5833
# Epoch 15/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.9353 - accuracy: 0.5637 - val_loss: 0.6886 - val_accuracy: 0.5833
# Epoch 16/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.9625 - accuracy: 0.5654 - val_loss: 0.6763 - val_accuracy: 0.5972
# Epoch 17/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.9525 - accuracy: 0.5515 - val_loss: 0.6512 - val_accuracy: 0.6250
# Epoch 18/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.7672 - accuracy: 0.6300 - val_loss: 0.7095 - val_accuracy: 0.5972
# Epoch 19/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.8362 - accuracy: 0.6003 - val_loss: 0.6887 - val_accuracy: 0.5833
# Epoch 20/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.8623 - accuracy: 0.5689 - val_loss: 0.6465 - val_accuracy: 0.6319
# Epoch 21/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0
100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5813 - accuracy: 0.6998 - val_loss: 0.6434 - val_accuracy: 0.6319
# Epoch 53/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5795 - accuracy: 0.6876 - val_loss: 0.6258 - val_accuracy: 0.6597
# Epoch 54/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5481 - accuracy: 0.7155 - val_loss: 0.6415 - val_accuracy: 0.6597
# Epoch 55/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5674 - accuracy: 0.7190 - val_loss: 0.6189 - val_accuracy: 0.6389
# Epoch 56/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5933 - accuracy: 0.6736 - val_loss: 0.6423 - val_accuracy: 0.6389
# Epoch 57/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5671 - accuracy: 0.7155 - val_loss: 0.6197 - val_accuracy: 0.6458
# Epoch 58/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5355 - accuracy: 0.7417 - val_loss: 0.6322 - val_accuracy: 0.6458
# Epoch 59/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5496 - accuracy: 0.7417 - val_loss: 0.6234 - val_accuracy: 0.6528
# Epoch 60/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.5446 - accuracy: 0.7260 - val_loss: 0.6239 - val_accuracy: 0.6458
# Epoch 61/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.5569 - accuracy: 0.7138 - val_loss: 0.6275 - val_accuracy: 0.6458
# 10/10 [==============================] - 0s 4ms/step
# Accuracy on test data: 0.68
#               precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70       159
#            1       0.68      0.63      0.66       149
#
#     accuracy                           0.68       308
#    macro avg       0.68      0.68      0.68       308
# weighted avg       0.68      0.68      0.68       308

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(14, 5))

# Plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='best')

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Bar Graph based on all accuracies obtained by different algoritms

# %%
import matplotlib.pyplot as plt

algorithms = ['FNN', 'MLP', 'DNN']
accuracies = [0.79, 0.83, 0.72]  

# Create the bar plot
plt.figure(figsize=(8, 6))
bars = plt.bar(algorithms, accuracies, color='lightgreen', width=0.5)

# Add the accuracy value inside each bar
for bar in bars:
    yval = bar.get_height()  # Get the height of the bar (accuracy value)
    plt.text(bar.get_x() + bar.get_width() / 2, yval / 2, f'{yval:.2f}', ha='center', va='center', color='blue', fontsize=12)

# Add labels and title
plt.xlabel('Algorithms', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.title('Comparison of Heart Disease Prediction Algorithms', fontsize=14)

# Display the plot
plt.ylim(0, 1)  # To ensure the accuracy values are within the 0-1 range
plt.show()

# %%
# import joblib

# # Save each model
# joblib.dump(fnn_model, 'fnn_model.pkl')
# joblib.dump(mlp_model, 'mlp_model.pkl')
# joblib.dump(dnn_model, 'dnn_model.pkl')

# print("Models saved successfully!")
# Out:
# Models saved successfully!

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### I Predicted Heart Diseases based on Machine Learning Algorithms such as:
# - Support Vector Machine(SVM) : Accuracy is 68%
# - K Nearest Neighbors(KNN)    : Accuracy is 71%
# - Decision Tree               : Accuracy is 97%
# - Logistic Regression         : Accuracy is 81%
# - Random Forest               : Accuracy is 98%
# ### The best accuracy was obtained in Random Forest  & Decision Tree.

# %% [markdown]
# ### I Predicted Heart Diseases based on Machine Learning Algorithms such as:
# - Feedforward Neural Networks(FNN) : Accuracy is 99%
# - Multilayer Perceptrons(MLP)      : Accuracy is 97%
# - Deep Neural Network              : Accuracy is 100%
# ### The best accuracy was obtained in Deep Neural Network.

# %% [markdown]
# # Finally I conclude that the best accuracy was obtained using Deep neural Network with many hidden layers
